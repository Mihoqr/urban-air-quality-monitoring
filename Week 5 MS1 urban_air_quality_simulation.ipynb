# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Number of simulated IoT readings
num_records = 100

# Data list for urban air quality monitoring
data = []

for _ in range(num_records):
    record = {
        "timestamp": datetime.now() - timedelta(minutes=np.random.randint(0, 1440)),  # Last 24 hours
        "station_id": f"Station_{np.random.choice(['A', 'B', 'C'])}",
        "PM2.5": round(np.random.uniform(5, 200), 1),  # PM2.5 µg/m³
        "CO2": round(np.random.uniform(300, 600), 1),  # CO2 ppm
        "temperature": round(np.random.uniform(15.0, 35.0), 1),  # Celsius
        "humidity": round(np.random.uniform(20.0, 80.0), 1),  # %
        "AQI": np.random.randint(0, 300)  # Simulated AQI index
    }
    data.append(record)

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to files
df.to_csv("urban_air_quality_data.csv", index=False)
df.to_json("urban_air_quality_data.json", orient="records")

# Display first rows
df.head()
# Out:
#                    timestamp station_id  PM2.5    CO2  temperature  humidity  \
# 0 2025-06-14 21:57:48.573103  Station_C  145.5  389.8         24.8      43.8
# 1 2025-06-14 20:44:48.573701  Station_B  190.0  522.8         31.6      58.8
# 2 2025-06-15 03:52:48.573757  Station_A  125.2  488.0         23.5      49.0
# 3 2025-06-15 16:20:48.573800  Station_B  131.9  541.3         28.6      47.1
# 4 2025-06-15 02:05:48.573840  Station_B   43.5  463.4         27.5      22.4
#
#    AQI
# 0  105
# 1  222
# 2  266
# 3   96
# 4   33

# %%
# !pip install web3
# Out:
# Requirement already satisfied: web3 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (7.12.0)
# Requirement already satisfied: eth-abi>=5.0.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (5.2.0)
# Requirement already satisfied: eth-account>=0.13.6 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (0.13.7)
# Requirement already satisfied: eth-hash>=0.5.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-hash[pycryptodome]>=0.5.1->web3) (0.7.1)
# Requirement already satisfied: eth-typing>=5.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (5.2.1)
# Requirement already satisfied: eth-utils>=5.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (5.3.0)
# Requirement already satisfied: hexbytes>=1.2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (1.3.1)
# Requirement already satisfied: aiohttp>=3.7.4.post0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (3.12.2)
# Requirement already satisfied: pydantic>=2.4.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (2.11.5)
# Requirement already satisfied: pywin32>=223 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (310)
# Requirement already satisfied: requests>=2.23.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (4.13.2)
# Requirement already satisfied: types-requests>=2.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (2.32.0.20250515)
# Requirement already satisfied: websockets<16.0.0,>=10.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (15.0.1)
# Requirement already satisfied: pyunormalize>=15.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from web3) (16.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.20.0)
# Requirement already satisfied: parsimonious<0.11.0,>=0.10.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-abi>=5.0.1->web3) (0.10.0)
# Requirement already satisfied: bitarray>=2.4.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-account>=0.13.6->web3) (3.4.2)
# Requirement already satisfied: eth-keyfile<0.9.0,>=0.7.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-account>=0.13.6->web3) (0.8.1)
# Requirement already satisfied: eth-keys>=0.4.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-account>=0.13.6->web3) (0.7.0)
# Requirement already satisfied: eth-rlp>=2.1.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-account>=0.13.6->web3) (2.2.0)
# Requirement already satisfied: rlp>=1.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-account>=0.13.6->web3) (4.1.0)
# Requirement already satisfied: ckzg>=2.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-account>=0.13.6->web3) (2.1.1)
# Requirement already satisfied: pycryptodome<4,>=3.6.6 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-hash[pycryptodome]>=0.5.1->web3) (3.23.0)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from eth-utils>=5.0.0->web3) (1.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.4.0->web3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.4.0->web3) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.4.0->web3) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->web3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->web3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->web3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->web3) (2025.4.26)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3) (1.0.0)
# Requirement already satisfied: regex>=2022.3.15 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3) (2024.11.6)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from web3 import Web3


# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
#Week 5 - Milestone 1: Smart Tracking System Blockchain Ledger (Submission)
import pandas as pd


# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("urban_air_quality_data.csv")


# Display the first few rows
print(df.head())
# Out:
#                     timestamp station_id  PM2.5    CO2  temperature  humidity  \
# 0  2025-06-14 21:57:48.573103  Station_C  145.5  389.8         24.8      43.8
# 1  2025-06-14 20:44:48.573701  Station_B  190.0  522.8         31.6      58.8
# 2  2025-06-15 03:52:48.573757  Station_A  125.2  488.0         23.5      49.0
# 3  2025-06-15 16:20:48.573800  Station_B  131.9  541.3         28.6      47.1
# 4  2025-06-15 02:05:48.573840  Station_B   43.5  463.4         27.5      22.4
#
#    AQI
# 0  105
# 1  222
# 2  266
# 3   96
# 4   33

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Replace with actual contract address from Remix
contract_address = "0x9E1B21D5303d2e5061F8316618e2599FA161e6dC"


# Paste the ABI from Remix
abi = [
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "pm25",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "co2",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "temperature",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "humidity",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "aqi",
				"type": "uint256"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "pm25",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "co2",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "temperature",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "humidity",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "aqi",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_deviceId",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "_pm25",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_co2",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_temperature",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_humidity",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_aqi",
				"type": "uint256"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	}
]  # Replace with your contract ABI


# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x9E1B21D5303d2e5061F8316618e2599FA161e6dC

# %%
import pandas as pd
import time

# Load CSV data (update the file name as needed)
df = pd.read_csv("urban_air_quality_data.csv")

def send_iot_data(device_id, pm25, co2, temperature, humidity, aqi):
    """Sends IoT sensor data to the deployed smart contract"""
    try:
        txn = contract.functions.storeData(
            device_id, pm25, co2, temperature, humidity, aqi
        ).transact({
            'from': web3.eth.default_account,
            'gas': 3000000
        })

        receipt = web3.eth.wait_for_transaction_receipt(txn)
        print(f"Data stored for {device_id}, Transaction Hash: {receipt.transactionHash.hex()}")
    except Exception as e:
        print(f"Failed to store data for {device_id}: {e}")

# Start sending data
print("Starting to send IoT data rows...\n")

print("Row count:", len(df))
print(df.head(), "\n")

for _, row in df.iterrows():
    print("Sending row:", row.to_dict())

    send_iot_data(
        str(row["station_id"]),               # device_id
        int(round(row["PM2.5"])),             # pm25
        int(round(row["CO2"])),               # co2
        int(round(row["temperature"])),       # temperature
        int(round(row["humidity"])),          # humidity
        int(round(row["AQI"]))                # aqi
    )

    time.sleep(1)

# Check results after sending all rows
total_records = contract.functions.getTotalRecords().call()
print(f"\nTotal IoT records stored: {total_records}")

record = contract.functions.getRecord(0).call()
print("First stored record:", record)

try:
    contract
except NameError:
    raise Exception("❌ Contract not defined. Please run the cell that sets up the smart contract.")
# Out:
# Starting to send IoT data rows...
#
# Row count: 100
#                     timestamp station_id  PM2.5    CO2  temperature  humidity  \
# 0  2025-06-14 21:57:48.573103  Station_C  145.5  389.8         24.8      43.8
# 1  2025-06-14 20:44:48.573701  Station_B  190.0  522.8         31.6      58.8
# 2  2025-06-15 03:52:48.573757  Station_A  125.2  488.0         23.5      49.0
# 3  2025-06-15 16:20:48.573800  Station_B  131.9  541.3         28.6      47.1
# 4  2025-06-15 02:05:48.573840  Station_B   43.5  463.4         27.5      22.4
#
#    AQI
# 0  105
# 1  222
# 2  266
# 3   96
# 4   33
#
# Sending row: {'timestamp': '2025-06-14 21:57:48.573103', 'station_id': 'Station_C', 'PM2.5': 145.5, 'CO2': 389.8, 'temperature': 24.8, 'humidity': 43.8, 'AQI': 105}
# Data stored for Station_C, Transaction Hash: c529eef773472ac6837e8a8cf5de82d56c4ef29869a4c15eaa1194a21dbad744
# Sending row: {'timestamp': '2025-06-14 20:44:48.573701', 'station_id': 'Station_B', 'PM2.5': 190.0, 'CO2': 522.8, 'temperature': 31.6, 'humidity': 58.8, 'AQI': 222}
# Data stored for Station_B, Transaction Hash: f84e0f985a9faba9c721068af4442a216812ee3ecf42f0ba587482717d0e1757
# Sending row: {'timestamp': '2025-06-15 03:52:48.573757', 'station_id': 'Station_A', 'PM2.5': 125.2, 'CO2': 488.0, 'temperature': 23.5, 'humidity': 49.0, 'AQI': 266}
# Data stored for Station_A, Transaction Hash: c64a7e8ae9567df8146865b6098c53155ee4975a3b1d3f1c15254eac01b2ca6c
# Sending row: {'timestamp': '2025-06-15 16:20:48.573800', 'station_id': 'Station_B', 'PM2.5': 131.9, 'CO2': 541.3, 'temperature': 28.6, 'humidity': 47.1, 'AQI': 96}
# Data stored for Station_B, Transaction Hash: 48b666b530e118059f613c9cbabc941f148170a73ce7020609636d935dd4611e
# Sending row: {'timestamp': '2025-06-15 02:05:48.573840', 'station_id': 'Station_B', 'PM2.5': 43.5, 'CO2': 463.4, 'temperature': 27.5, 'humidity': 22.4, 'AQI': 33}
# Data stored for Station_B, Transaction Hash: dd7bc5f6b9bd52ffaa97b4cd4ab1d957ddd1c33fb91a3af1adb82f315fb0876d
# Sending row: {'timestamp': '2025-06-15 04:45:48.573879', 'station_id': 'Station_B', 'PM2.5': 107.1, 'CO2': 323.5, 'temperature': 15.3, 'humidity': 61.0, 'AQI': 252}
# Data stored for Station_B, Transaction Hash: 6e4c29647ed2a998f3f78649851f9c75a1aab8d8b47ac764dbc8ffd77fb36395
# Sending row: {'timestamp': '2025-06-14 22:44:48.573916', 'station_id': 'Station_A', 'PM2.5': 112.0, 'CO2': 479.9, 'temperature': 30.2, 'humidity': 61.4, 'AQI': 151}
# Data stored for Station_A, Transaction Hash: 594e3e68f2bccba7a6d49b222e82e8a746c91212ffa0f1ca0a715db7ffd71b53
# Sending row: {'timestamp': '2025-06-14 23:01:48.573953', 'station_id': 'Station_A', 'PM2.5': 164.3, 'CO2': 498.4, 'temperature': 17.7, 'humidity': 77.8, 'AQI': 262}
# Data stored for Station_A, Transaction Hash: 918d705491729eb50506c8cb99576b259fbb7bce69a4d7c8220d23b7c6198259
# Sending row: {'timestamp': '2025-06-15 01:16:48.573993', 'station_id': 'Station_B', 'PM2.5': 195.0, 'CO2': 392.4, 'temperature': 27.3, 'humidity': 75.2, 'AQI': 107}
# Data stored for Station_B, Transaction Hash: e45088c9b55e0e41b15b22bda318878296f8be84ba9a988eccf3cf7f5bf5f3f0
# Sending row: {'timestamp': '2025-06-15 12:02:48.574030', 'station_id': 'Station_C', 'PM2.5': 29.4, 'CO2': 332.9, 'temperature': 28.4, 'humidity': 52.6, 'AQI': 171}
# Data stored for Station_C, Transaction Hash: 406daaf0be35fb302be7fe6ce7d38ec33382e2dfbba663308ea23825d03ed44f
# Sending row: {'timestamp': '2025-06-15 06:57:48.574066', 'station_id': 'Station_C', 'PM2.5': 55.1, 'CO2': 586.2, 'temperature': 20.2, 'humidity': 61.8, 'AQI': 185}
# Data stored for Station_C, Transaction Hash: b838050dd084b8ca936cbcdb8b160dd58f4382ff767b7e9aac9e1dda7e4e62d8
# Sending row: {'timestamp': '2025-06-15 03:18:48.574103', 'station_id': 'Station_C', 'PM2.5': 130.3, 'CO2': 466.1, 'temperature': 29.2, 'humidity': 69.4, 'AQI': 189}
# Data stored for Station_C, Transaction Hash: 323a94c0bb0d57b99a44885988e0321f1a82a670814c214a1ce25be2e912793f
# Sending row: {'timestamp': '2025-06-15 12:59:48.574140', 'station_id': 'Station_B', 'PM2.5': 173.9, 'CO2': 374.3, 'temperature': 33.1, 'humidity': 59.4, 'AQI': 45}
# Data stored for Station_B, Transaction Hash: e6df1ee2a6ce0f5f0787a6c46c7b554d1b71cda82c02ca9992447fb800d5cbf8
# Sending row: {'timestamp': '2025-06-15 10:15:48.574176', 'station_id': 'Station_C', 'PM2.5': 104.2, 'CO2': 476.4, 'temperature': 29.4, 'humidity': 30.6, 'AQI': 268}
# Data stored for Station_C, Transaction Hash: 0999498e3c3b18d5e9bdf4e36958435a2c58fc807e51a7929554e99d9fd2b680
# Sending row: {'timestamp': '2025-06-14 21:31:48.574213', 'station_id': 'Station_B', 'PM2.5': 58.2, 'CO2': 403.6, 'temperature': 19.6, 'humidity': 54.3, 'AQI': 19}
# Data stored for Station_B, Transaction Hash: 3ce3b029b9646e832874440d21670d8b6f462709ff0f8025331ee4f51e1eb26d
# Sending row: {'timestamp': '2025-06-15 07:25:48.574249', 'station_id': 'Station_B', 'PM2.5': 86.9, 'CO2': 536.6, 'temperature': 25.9, 'humidity': 71.3, 'AQI': 126}
# Data stored for Station_B, Transaction Hash: 0388af9426b63cd75d7f7c082c033498f9e47b14bdbb6e2f8fbbfdb2bd2b5831
# Sending row: {'timestamp': '2025-06-15 00:54:48.574289', 'station_id': 'Station_B', 'PM2.5': 133.9, 'CO2': 440.1, 'temperature': 19.5, 'humidity': 74.4, 'AQI': 34}
# Data stored for Station_B, Transaction Hash: 691714d85a968bc1038f1ba04f585a9e6725c993c48f8cf4d029245d5fbc54fe
# Sending row: {'timestamp': '2025-06-15 10:39:48.574325', 'station_id': 'Station_B', 'PM2.5': 197.9, 'CO2': 389.0, 'temperature': 20.6, 'humidity': 49.2, 'AQI': 180}
# Data stored for Station_B, Transaction Hash: 0dabe5c225bf372ad93093d36737f1cc1f95244d8e134cb1913a70c1f9662c15
# Sending row: {'timestamp': '2025-06-15 11:22:48.574362', 'station_id': 'Station_A', 'PM2.5': 55.9, 'CO2': 483.7, 'temperature': 22.3, 'humidity': 51.1, 'AQI': 93}
# Data stored for Station_A, Transaction Hash: a521b3c04e2f00c27a90f9bcd6b88dccc89c5759daf1f31de1e396dddc291288
# Sending row: {'timestamp': '2025-06-15 03:59:48.574398', 'station_id': 'Station_A', 'PM2.5': 165.7, 'CO2': 433.7, 'temperature': 28.3, 'humidity': 56.2, 'AQI': 13}
# Data stored for Station_A, Transaction Hash: 7b303605e1ab1ed22b19fe1e57fe3f35b2933821dead9d17ab0d1008ee49c7e3
# Sending row: {'timestamp': '2025-06-15 02:49:48.574434', 'station_id': 'Station_B', 'PM2.5': 172.9, 'CO2': 368.3, 'temperature': 20.8, 'humidity': 73.6, 'AQI': 255}
# Data stored for Station_B, Transaction Hash: ec21c359357a2f8a0ad8d8663da116b862eb9e7b0100f1810e340c14959318e6
# Sending row: {'timestamp': '2025-06-15 01:23:48.574469', 'station_id': 'Station_B', 'PM2.5': 47.0, 'CO2': 424.1, 'temperature': 26.0, 'humidity': 44.9, 'AQI': 255}
# Data stored for Station_B, Transaction Hash: 51992c109cc4558c6277964c4f8c0323327523c5c7dbce7286700659fe43296f
# Sending row: {'timestamp': '2025-06-14 21:04:48.574538', 'station_id': 'Station_A', 'PM2.5': 13.9, 'CO2': 445.3, 'temperature': 27.3, 'humidity': 33.2, 'AQI': 131}
# Data stored for Station_A, Transaction Hash: fd137b106c4ad75c9cc46b372d93292f5083875d11adcf28b7c8e79ed4794a68
# Sending row: {'timestamp': '2025-06-15 02:32:48.574595', 'station_id': 'Station_B', 'PM2.5': 182.5, 'CO2': 367.2, 'temperature': 15.8, 'humidity': 61.5, 'AQI': 262}
# Data stored for Station_B, Transaction Hash: 5412672f1bd13b2a434479c17c6e8e69b313979be929127d509c73560719b516
# Sending row: {'timestamp': '2025-06-15 14:14:48.574639', 'station_id': 'Station_B', 'PM2.5': 167.0, 'CO2': 323.6, 'temperature': 32.8, 'humidity': 23.3, 'AQI': 80}
# Data stored for Station_B, Transaction Hash: 1f3400fec55fcdf955c397415f05660993f8ccf65eb0c2520f25ffa3147e0c32
# Sending row: {'timestamp': '2025-06-15 16:22:48.574678', 'station_id': 'Station_A', 'PM2.5': 154.2, 'CO2': 396.4, 'temperature': 26.1, 'humidity': 26.2, 'AQI': 26}
# Data stored for Station_A, Transaction Hash: 39a32b61b6c860b7d53e79041d0d660e67ec1ea684b53556e0dc03c27d88b8ad
# Sending row: {'timestamp': '2025-06-15 07:12:48.574715', 'station_id': 'Station_C', 'PM2.5': 148.3, 'CO2': 303.1, 'temperature': 22.2, 'humidity': 23.8, 'AQI': 137}
# Data stored for Station_C, Transaction Hash: 5e3c7c97b32baf47692b445b083eb803515695bb9962e63753c91834901ab4b0
# Sending row: {'timestamp': '2025-06-14 21:48:48.574761', 'station_id': 'Station_A', 'PM2.5': 41.5, 'CO2': 421.8, 'temperature': 16.3, 'humidity': 66.9, 'AQI': 214}
# Data stored for Station_A, Transaction Hash: f18bcb7646a6eab7170e88ad7d8630ba32ad13a1b45feb67dc6efb453a09e981
# Sending row: {'timestamp': '2025-06-15 09:00:48.574802', 'station_id': 'Station_A', 'PM2.5': 158.7, 'CO2': 450.9, 'temperature': 16.3, 'humidity': 44.1, 'AQI': 291}
# Data stored for Station_A, Transaction Hash: d984cec2e2c546c25e82da4a9832dd34075d6909960e4ef937b41a2f432b85a9
# Sending row: {'timestamp': '2025-06-15 17:10:48.574838', 'station_id': 'Station_C', 'PM2.5': 26.1, 'CO2': 496.4, 'temperature': 28.1, 'humidity': 21.6, 'AQI': 299}
# Data stored for Station_C, Transaction Hash: 3fedefd5d9a8096612f8436a593028c4936884b2d23c783d67224d019ef1d983
# Sending row: {'timestamp': '2025-06-15 12:31:48.574874', 'station_id': 'Station_B', 'PM2.5': 71.5, 'CO2': 427.0, 'temperature': 22.7, 'humidity': 71.6, 'AQI': 17}
# Data stored for Station_B, Transaction Hash: 62918e4ac0616f35415a6c33c7be418e19382bd099aeaa9cdd8c4adbeab47581
# Sending row: {'timestamp': '2025-06-14 19:11:48.574910', 'station_id': 'Station_C', 'PM2.5': 137.5, 'CO2': 479.4, 'temperature': 23.9, 'humidity': 28.1, 'AQI': 179}
# Data stored for Station_C, Transaction Hash: 81214f79b680f5ae1f2aae0003a907eb3a07125eadfd8a46a0319d748d6a7274
# Sending row: {'timestamp': '2025-06-15 07:09:48.574946', 'station_id': 'Station_C', 'PM2.5': 176.0, 'CO2': 470.5, 'temperature': 22.5, 'humidity': 43.1, 'AQI': 94}
# Data stored for Station_C, Transaction Hash: 9cf68e4cb12844885a8dcb79850cf846e911b5236bc7a9153893d88679058fd5
# Sending row: {'timestamp': '2025-06-15 04:24:48.574982', 'station_id': 'Station_B', 'PM2.5': 130.2, 'CO2': 306.5, 'temperature': 34.8, 'humidity': 29.7, 'AQI': 11}
# Data stored for Station_B, Transaction Hash: 54c21461ec2cc93b853ed33d6c057e49cad972bbde92278ecc0fbaacf121844e
# Sending row: {'timestamp': '2025-06-15 07:09:48.575021', 'station_id': 'Station_C', 'PM2.5': 52.0, 'CO2': 383.9, 'temperature': 21.7, 'humidity': 61.3, 'AQI': 97}
# Data stored for Station_C, Transaction Hash: 5ea65eabf574d48acc8c2da1945592bc9a7b880066a6dc7a7d467917276cc9a3
# Sending row: {'timestamp': '2025-06-15 10:50:48.575058', 'station_id': 'Station_A', 'PM2.5': 52.9, 'CO2': 412.6, 'temperature': 34.0, 'humidity': 39.6, 'AQI': 27}
# Data stored for Station_A, Transaction Hash: 82672b916da04f0bdc641022b7385bb12dac4b76fc9f49a1935007517deed1f6
# Sending row: {'timestamp': '2025-06-14 20:35:48.575093', 'station_id': 'Station_A', 'PM2.5': 188.2, 'CO2': 519.7, 'temperature': 18.2, 'humidity': 57.2, 'AQI': 84}
# Data stored for Station_A, Transaction Hash: 55b14810a95de057db3763f9b81584497dffcfb7e5306d6891cba4d6eb2befe2
# Sending row: {'timestamp': '2025-06-14 19:56:48.575129', 'station_id': 'Station_C', 'PM2.5': 136.6, 'CO2': 317.5, 'temperature': 28.0, 'humidity': 74.5, 'AQI': 258}
# Data stored for Station_C, Transaction Hash: bf87deca160d95c0aad5fab3dbbeb4623d83d196fe679c3d24404ff91b9e0358
# Sending row: {'timestamp': '2025-06-15 02:06:48.575164', 'station_id': 'Station_C', 'PM2.5': 20.5, 'CO2': 477.3, 'temperature': 28.6, 'humidity': 22.4, 'AQI': 178}
# Data stored for Station_C, Transaction Hash: b265222a17329329edd72c921ee048609b86498090930704559fe74d261eccf0
# Sending row: {'timestamp': '2025-06-14 22:16:48.575200', 'station_id': 'Station_C', 'PM2.5': 112.8, 'CO2': 509.9, 'temperature': 35.0, 'humidity': 33.1, 'AQI': 280}
# Data stored for Station_C, Transaction Hash: 28a038d6f62c7c96b953b62766e728ab60d7e1b4124bd3c908637ecc6741b428
# Sending row: {'timestamp': '2025-06-15 01:17:48.575235', 'station_id': 'Station_B', 'PM2.5': 174.6, 'CO2': 307.3, 'temperature': 24.6, 'humidity': 47.4, 'AQI': 247}
# Data stored for Station_B, Transaction Hash: d125ebbe2b06b3b4b0952f6a93bd3846d76af983c06e1d042b1470afece615e2
# Sending row: {'timestamp': '2025-06-14 22:26:48.575271', 'station_id': 'Station_B', 'PM2.5': 21.2, 'CO2': 395.7, 'temperature': 19.2, 'humidity': 51.8, 'AQI': 279}
# Data stored for Station_B, Transaction Hash: 3133998ba05b8ba9f6aa549499f9efad37b746b59a315b1e856413c0a1cf3ad1
# Sending row: {'timestamp': '2025-06-15 17:02:48.575309', 'station_id': 'Station_C', 'PM2.5': 38.3, 'CO2': 509.1, 'temperature': 27.1, 'humidity': 35.7, 'AQI': 287}
# Data stored for Station_C, Transaction Hash: 3aea7eb7fdc98b424be27c587635747ff552c0a418da5cefc4321c8835be47a8
# Sending row: {'timestamp': '2025-06-15 01:38:48.575345', 'station_id': 'Station_C', 'PM2.5': 83.2, 'CO2': 584.8, 'temperature': 24.2, 'humidity': 38.3, 'AQI': 57}
# Data stored for Station_C, Transaction Hash: a17f43303668235df0d2905244ef4a70cb3b1ae60f71b89d5334bbdc635d7953
# Sending row: {'timestamp': '2025-06-15 04:27:48.575380', 'station_id': 'Station_C', 'PM2.5': 101.0, 'CO2': 538.1, 'temperature': 23.7, 'humidity': 45.4, 'AQI': 191}
# Data stored for Station_C, Transaction Hash: 12747c22fed81c499992a25d766a80b41fdb0cb63a78756c586dab9f3cd9c2a2
# Sending row: {'timestamp': '2025-06-15 00:09:48.575415', 'station_id': 'Station_A', 'PM2.5': 71.7, 'CO2': 327.2, 'temperature': 33.5, 'humidity': 54.0, 'AQI': 74}
# Data stored for Station_A, Transaction Hash: e580bb9b64091f30711dae1571dca138f7fe1913b86e387748228973172fdb84
# Sending row: {'timestamp': '2025-06-15 03:08:48.575454', 'station_id': 'Station_B', 'PM2.5': 196.2, 'CO2': 306.9, 'temperature': 20.4, 'humidity': 61.9, 'AQI': 67}
# Data stored for Station_B, Transaction Hash: 6b6451dca128851d82e6f05d468234e3585fa2088245d431ac921e0a06fdaf23
# Sending row: {'timestamp': '2025-06-15 13:25:48.575491', 'station_id': 'Station_A', 'PM2.5': 89.4, 'CO2': 460.9, 'temperature': 29.2, 'humidity': 24.5, 'AQI': 258}
# Data stored for Station_A, Transaction Hash: e4c42cc557ed18bc98c7484b3036346d8c642ed2de7133b3d880cfe6619df03d
# Sending row: {'timestamp': '2025-06-15 01:37:48.575527', 'station_id': 'Station_A', 'PM2.5': 126.8, 'CO2': 541.9, 'temperature': 25.6, 'humidity': 30.9, 'AQI': 111}
# Data stored for Station_A, Transaction Hash: 19f60c8662fd368e03a19f4d3c8977abcc890456d814988237975ceb545394f6
# Sending row: {'timestamp': '2025-06-15 00:59:48.575564', 'station_id': 'Station_A', 'PM2.5': 99.0, 'CO2': 480.8, 'temperature': 27.3, 'humidity': 26.9, 'AQI': 66}
# Data stored for Station_A, Transaction Hash: 82a760039561a5f77ace2189e11c692a94b2083088d4f47630fdb27cfda00441
# Sending row: {'timestamp': '2025-06-14 22:21:48.575603', 'station_id': 'Station_C', 'PM2.5': 165.2, 'CO2': 415.6, 'temperature': 25.8, 'humidity': 46.9, 'AQI': 103}
# Data stored for Station_C, Transaction Hash: d70aade0a925210c7227d6d450cbaecf0fd1c0e99437f89421f0db15fc346148
# Sending row: {'timestamp': '2025-06-15 06:03:48.575639', 'station_id': 'Station_B', 'PM2.5': 29.8, 'CO2': 535.6, 'temperature': 24.6, 'humidity': 30.9, 'AQI': 107}
# Data stored for Station_B, Transaction Hash: 115f6f0872a5d5c6b37f64ea4a980939c363d1ea368a9689905f3388a86a48c5
# Sending row: {'timestamp': '2025-06-15 00:47:48.575674', 'station_id': 'Station_C', 'PM2.5': 193.3, 'CO2': 310.6, 'temperature': 31.2, 'humidity': 32.6, 'AQI': 201}
# Data stored for Station_C, Transaction Hash: 8acdd55cd147fbda355b334a6df42b373b83b8c05a1b0badfec1c0c2ed0a1701
# Sending row: {'timestamp': '2025-06-15 16:58:48.575709', 'station_id': 'Station_B', 'PM2.5': 51.1, 'CO2': 524.2, 'temperature': 26.7, 'humidity': 43.7, 'AQI': 48}
# Data stored for Station_B, Transaction Hash: f19d923ea2064064eb9e0ae9555492bacf2694e9ffd7df17868d6762650b5292
# Sending row: {'timestamp': '2025-06-15 04:19:48.575745', 'station_id': 'Station_C', 'PM2.5': 34.0, 'CO2': 437.8, 'temperature': 30.7, 'humidity': 79.0, 'AQI': 22}
# Data stored for Station_C, Transaction Hash: c2c0778b661f645daf9f63bf00dd21f5e6fe9fea6c8f782384fcb55e9418784f
# Sending row: {'timestamp': '2025-06-15 00:52:48.575780', 'station_id': 'Station_B', 'PM2.5': 56.5, 'CO2': 552.2, 'temperature': 18.1, 'humidity': 63.4, 'AQI': 263}
# Data stored for Station_B, Transaction Hash: 7e9c163c90d78e4961eb6c7e0bec444c32285966ed78f30dd4832b1039b29124
# Sending row: {'timestamp': '2025-06-15 06:42:48.575815', 'station_id': 'Station_B', 'PM2.5': 51.4, 'CO2': 450.5, 'temperature': 16.5, 'humidity': 67.0, 'AQI': 89}
# Data stored for Station_B, Transaction Hash: 44ba86140f308b9aa361771c2b245d8a46167699921f6adb1b7d32d481f597a9
# Sending row: {'timestamp': '2025-06-14 18:08:48.575852', 'station_id': 'Station_C', 'PM2.5': 67.2, 'CO2': 441.2, 'temperature': 34.4, 'humidity': 22.0, 'AQI': 108}
# Data stored for Station_C, Transaction Hash: 81e11802b7bad20416e95dbcc91ae19c6e85dc9a9e947fa0f6313206ed2fa222
# Sending row: {'timestamp': '2025-06-14 20:15:48.575892', 'station_id': 'Station_C', 'PM2.5': 74.6, 'CO2': 309.0, 'temperature': 21.7, 'humidity': 75.9, 'AQI': 162}
# Data stored for Station_C, Transaction Hash: 20f7fe9b1e21163f2f8da65b529e63adc0ee7950ce83127ccbe31a9258d63cf0
# Sending row: {'timestamp': '2025-06-15 01:59:48.575928', 'station_id': 'Station_C', 'PM2.5': 151.3, 'CO2': 509.5, 'temperature': 32.9, 'humidity': 37.8, 'AQI': 23}
# Data stored for Station_C, Transaction Hash: 387e473d9db0bbc5adfbabc7bece2483df8b606ca343be24c5ef36b9e4b874f1
# Sending row: {'timestamp': '2025-06-15 13:18:48.575963', 'station_id': 'Station_C', 'PM2.5': 6.8, 'CO2': 422.9, 'temperature': 19.6, 'humidity': 57.8, 'AQI': 56}
# Data stored for Station_C, Transaction Hash: 89829fe22ae6c38877e96a4c3882d6929275221af132832d9a63eb73ff045906
# Sending row: {'timestamp': '2025-06-15 14:52:48.575998', 'station_id': 'Station_A', 'PM2.5': 166.6, 'CO2': 573.1, 'temperature': 17.0, 'humidity': 34.6, 'AQI': 34}
# Data stored for Station_A, Transaction Hash: c2adb346076efec7eadc4d00f689b68cf1bdac6718363e4de0657d3a4d47e358
# Sending row: {'timestamp': '2025-06-14 19:37:48.576033', 'station_id': 'Station_C', 'PM2.5': 105.2, 'CO2': 391.8, 'temperature': 27.5, 'humidity': 44.6, 'AQI': 167}
# Data stored for Station_C, Transaction Hash: 1e3ef0f7d957cc3bef06eff8c4185234ac5110988f34c272c9cbe9a27789b9ad
# Sending row: {'timestamp': '2025-06-14 19:18:48.576068', 'station_id': 'Station_C', 'PM2.5': 191.0, 'CO2': 545.2, 'temperature': 32.3, 'humidity': 72.2, 'AQI': 74}
# Data stored for Station_C, Transaction Hash: cbabc9d74c413149f0a6f835be2f1079ec28804f7870a666b6c17c4f7c01c743
# Sending row: {'timestamp': '2025-06-15 13:21:48.576103', 'station_id': 'Station_B', 'PM2.5': 145.8, 'CO2': 396.4, 'temperature': 33.0, 'humidity': 21.1, 'AQI': 68}
# Data stored for Station_B, Transaction Hash: 3d465d304cdc32d83924fdc259956828d978a215753370b3916d6663ec2d8009
# Sending row: {'timestamp': '2025-06-15 12:22:48.576141', 'station_id': 'Station_B', 'PM2.5': 88.2, 'CO2': 317.0, 'temperature': 28.4, 'humidity': 40.3, 'AQI': 116}
# Data stored for Station_B, Transaction Hash: cdafa9c75264adb985a926ab1c0a0dd8d341db7415ee79567b922be8a897f626
# Sending row: {'timestamp': '2025-06-14 21:39:48.576179', 'station_id': 'Station_B', 'PM2.5': 179.8, 'CO2': 415.3, 'temperature': 23.0, 'humidity': 57.2, 'AQI': 37}
# Data stored for Station_B, Transaction Hash: 9b33f5d79ba960137661569b2cb35e920406e0ab7e7453dfeb6da3f64e77b9f7
# Sending row: {'timestamp': '2025-06-15 04:56:48.576215', 'station_id': 'Station_C', 'PM2.5': 155.2, 'CO2': 501.7, 'temperature': 29.1, 'humidity': 70.0, 'AQI': 150}
# Data stored for Station_C, Transaction Hash: 75b85094d9b7d055b24d222ac45ba8af0bc716a56247afe0c9eb8f55eac55874
# Sending row: {'timestamp': '2025-06-14 19:51:48.576253', 'station_id': 'Station_B', 'PM2.5': 27.8, 'CO2': 544.8, 'temperature': 30.3, 'humidity': 67.8, 'AQI': 49}
# Data stored for Station_B, Transaction Hash: 4731804c600091799897b6af894e588abce100216ae57505f86c6babd6dba92c
# Sending row: {'timestamp': '2025-06-14 19:56:48.576289', 'station_id': 'Station_B', 'PM2.5': 180.7, 'CO2': 337.9, 'temperature': 30.9, 'humidity': 37.6, 'AQI': 252}
# Data stored for Station_B, Transaction Hash: 1a3fce850e3c302d0f52e901b8302342d7f53b957f5df9f9abb6cbc8382487fb
# Sending row: {'timestamp': '2025-06-14 21:50:48.576324', 'station_id': 'Station_B', 'PM2.5': 49.6, 'CO2': 350.8, 'temperature': 18.8, 'humidity': 39.5, 'AQI': 69}
# Data stored for Station_B, Transaction Hash: 140aab4b0c0898f52c0a082d687ad33726ff95aafd066545bce601ce9ff1c00d
# Sending row: {'timestamp': '2025-06-15 17:56:48.576359', 'station_id': 'Station_B', 'PM2.5': 102.6, 'CO2': 422.7, 'temperature': 19.7, 'humidity': 37.7, 'AQI': 260}
# Data stored for Station_B, Transaction Hash: 88384017374dcca3d42fc65fd258a52cd0fd846fe3f85875e7bc8f4d2179c60d
# Sending row: {'timestamp': '2025-06-15 01:01:48.576394', 'station_id': 'Station_B', 'PM2.5': 28.5, 'CO2': 561.6, 'temperature': 28.6, 'humidity': 28.6, 'AQI': 192}
# Data stored for Station_B, Transaction Hash: f7c34d2bb729aa24eb6b6b0d99aa5e1919f05c153648fe24208abe317b22e61d
# Sending row: {'timestamp': '2025-06-14 19:45:48.576432', 'station_id': 'Station_B', 'PM2.5': 137.7, 'CO2': 433.2, 'temperature': 34.9, 'humidity': 68.7, 'AQI': 67}
# Data stored for Station_B, Transaction Hash: 1cefe9380a9291c8638dcf9b8346d1c29d7bfaff0a0ff35d597270b6ae76c27c
# Sending row: {'timestamp': '2025-06-14 21:25:48.576468', 'station_id': 'Station_C', 'PM2.5': 58.8, 'CO2': 568.4, 'temperature': 20.1, 'humidity': 52.0, 'AQI': 227}
# Data stored for Station_C, Transaction Hash: a1d7a1d2cc7991d94de53644f448122fc50cfe2883605e629097f039b92fd77b
# Sending row: {'timestamp': '2025-06-15 16:40:48.576503', 'station_id': 'Station_B', 'PM2.5': 41.3, 'CO2': 595.8, 'temperature': 21.4, 'humidity': 22.1, 'AQI': 103}
# Data stored for Station_B, Transaction Hash: cada27d5da259c7ed6a8bedbe70fc70a78829bc3066007615aa2b305468d6833
# Sending row: {'timestamp': '2025-06-14 19:29:48.576538', 'station_id': 'Station_A', 'PM2.5': 26.0, 'CO2': 423.9, 'temperature': 31.3, 'humidity': 68.6, 'AQI': 195}
# Data stored for Station_A, Transaction Hash: 88ad5cd390b884619b405bba70b6fc9aade9416df4e5004324f7f7a4f111a78d
# Sending row: {'timestamp': '2025-06-15 00:58:48.576574', 'station_id': 'Station_A', 'PM2.5': 110.4, 'CO2': 384.7, 'temperature': 29.1, 'humidity': 47.9, 'AQI': 108}
# Data stored for Station_A, Transaction Hash: db150bd2d79a62f2f0352fcadafe9e51c742f046c457eab50d368dc54f36cbef
# Sending row: {'timestamp': '2025-06-14 22:59:48.576609', 'station_id': 'Station_B', 'PM2.5': 147.2, 'CO2': 416.0, 'temperature': 26.1, 'humidity': 64.0, 'AQI': 100}
# Data stored for Station_B, Transaction Hash: 0cf1c0ee02f3edebd59af18f34bf0dfbe03f1ae5bc1e088700d8ff5691654f38
# Sending row: {'timestamp': '2025-06-15 15:53:48.576644', 'station_id': 'Station_C', 'PM2.5': 13.3, 'CO2': 317.9, 'temperature': 32.8, 'humidity': 56.6, 'AQI': 199}
# Data stored for Station_C, Transaction Hash: f09d183ed2042657bf23e840f969c8dc75105a6dc8a5ee2322af67753c5ff9a2
# Sending row: {'timestamp': '2025-06-15 07:32:48.576680', 'station_id': 'Station_C', 'PM2.5': 177.5, 'CO2': 516.1, 'temperature': 30.1, 'humidity': 56.4, 'AQI': 244}
# Data stored for Station_C, Transaction Hash: 46cda05a278858810cdc69fd4dbaf5c3c74711b6dd26fabb6c96911fe1a1e991
# Sending row: {'timestamp': '2025-06-15 17:18:48.576721', 'station_id': 'Station_B', 'PM2.5': 102.2, 'CO2': 327.7, 'temperature': 30.3, 'humidity': 20.3, 'AQI': 250}
# Data stored for Station_B, Transaction Hash: 0bdf2015b1013454c2a9fdd37f3a805ac654b0f584271256dbc20e140b2b279c
# Sending row: {'timestamp': '2025-06-15 05:21:48.576757', 'station_id': 'Station_C', 'PM2.5': 33.0, 'CO2': 337.1, 'temperature': 30.9, 'humidity': 40.9, 'AQI': 183}
# Data stored for Station_C, Transaction Hash: 8ad5ec6c258462a818320fcac00c90c159fc9750601e01e944305fb7478eaa33
# Sending row: {'timestamp': '2025-06-15 04:00:48.576792', 'station_id': 'Station_A', 'PM2.5': 77.7, 'CO2': 576.5, 'temperature': 20.8, 'humidity': 23.3, 'AQI': 178}
# Data stored for Station_A, Transaction Hash: 481257ddfa7adb34316a0b25a5f091929e2fe7f0fb17b639360f5e905c3239e5
# Sending row: {'timestamp': '2025-06-15 08:06:48.576827', 'station_id': 'Station_B', 'PM2.5': 40.0, 'CO2': 350.8, 'temperature': 27.1, 'humidity': 62.0, 'AQI': 256}
# Data stored for Station_B, Transaction Hash: c50f43a818f822e256acc9c46b0af7e0b99a564255cc6ccb8fd6bae1201aa135
# Sending row: {'timestamp': '2025-06-15 08:07:48.576862', 'station_id': 'Station_B', 'PM2.5': 155.2, 'CO2': 425.0, 'temperature': 22.5, 'humidity': 61.7, 'AQI': 202}
# Data stored for Station_B, Transaction Hash: a7ce91387e3efd5668ecee8e80d60fdfc2ea93acf28cd2805c8e9c76fa4897ec
# Sending row: {'timestamp': '2025-06-14 21:17:48.576900', 'station_id': 'Station_B', 'PM2.5': 95.8, 'CO2': 425.0, 'temperature': 16.1, 'humidity': 78.1, 'AQI': 286}
# Data stored for Station_B, Transaction Hash: 263b780579e204d2ad97d62bd2a3083616dd0e0bd712286b309d2af2f1411498
# Sending row: {'timestamp': '2025-06-14 23:42:48.576936', 'station_id': 'Station_A', 'PM2.5': 106.4, 'CO2': 566.2, 'temperature': 32.7, 'humidity': 55.0, 'AQI': 251}
# Data stored for Station_A, Transaction Hash: 278e3f094ed3c3592b4fb3774e0015ebc8a6202f8c31dca36781a7605bd9fc45
# Sending row: {'timestamp': '2025-06-15 09:37:48.576971', 'station_id': 'Station_A', 'PM2.5': 150.0, 'CO2': 450.8, 'temperature': 31.8, 'humidity': 54.8, 'AQI': 33}
# Data stored for Station_A, Transaction Hash: 1a16b31c1eea050d7f68366e416edf33e26ababf3d4e63ed155ec610f7f144db
# Sending row: {'timestamp': '2025-06-15 09:31:48.577012', 'station_id': 'Station_A', 'PM2.5': 70.9, 'CO2': 438.2, 'temperature': 16.7, 'humidity': 43.5, 'AQI': 174}
# Data stored for Station_A, Transaction Hash: fb9760c5345dac95b3ab80b8168976b2adc3f788d62f73637cdab52b49ca344a
# Sending row: {'timestamp': '2025-06-15 15:35:48.577047', 'station_id': 'Station_B', 'PM2.5': 36.0, 'CO2': 310.5, 'temperature': 33.6, 'humidity': 73.4, 'AQI': 78}
# Data stored for Station_B, Transaction Hash: 888446c60068dd33972cc5b063c9aa9587c4d4bb5235b190c69c0ee3678639e6
# Sending row: {'timestamp': '2025-06-14 23:11:48.577083', 'station_id': 'Station_C', 'PM2.5': 98.9, 'CO2': 578.0, 'temperature': 34.3, 'humidity': 79.0, 'AQI': 56}
# Data stored for Station_C, Transaction Hash: 40c019184c8522ad2c5925fdb75f09563a1cc9a7ddf38e4981272d8131996c14
# Sending row: {'timestamp': '2025-06-15 08:02:48.577118', 'station_id': 'Station_C', 'PM2.5': 119.7, 'CO2': 340.4, 'temperature': 22.1, 'humidity': 30.8, 'AQI': 56}
# Data stored for Station_C, Transaction Hash: 6b4f50c62e047b79e173f996d7e4b773367d047334336c1a8d3f4afac5e66ad7
# Sending row: {'timestamp': '2025-06-15 10:05:48.577153', 'station_id': 'Station_C', 'PM2.5': 180.0, 'CO2': 340.2, 'temperature': 24.6, 'humidity': 52.1, 'AQI': 204}
# Data stored for Station_C, Transaction Hash: 3e323022787d1c06373a2128c51c6a3984bab2b039963d8371ffc1baff6fe776
# Sending row: {'timestamp': '2025-06-15 04:50:48.577189', 'station_id': 'Station_C', 'PM2.5': 54.7, 'CO2': 551.9, 'temperature': 22.8, 'humidity': 35.4, 'AQI': 230}
# Data stored for Station_C, Transaction Hash: 8c47d17db305c1cae26207c3f5b20e2f17ffcb8da7d261fdd9919e29b18e60d4
# Sending row: {'timestamp': '2025-06-15 10:12:48.577224', 'station_id': 'Station_A', 'PM2.5': 8.1, 'CO2': 591.6, 'temperature': 23.8, 'humidity': 20.7, 'AQI': 28}
# Data stored for Station_A, Transaction Hash: 2a287e6a0bde4ecfff7f3a6c7f36038563ec9730f4fec2d12476ff6b1d895683
# Sending row: {'timestamp': '2025-06-15 15:04:48.577258', 'station_id': 'Station_C', 'PM2.5': 113.3, 'CO2': 448.3, 'temperature': 19.9, 'humidity': 70.9, 'AQI': 23}
# Data stored for Station_C, Transaction Hash: 15232374cac584750a6d29b1c04e8c2e02a072c519dcd643e4821ca957244967
# Sending row: {'timestamp': '2025-06-15 00:03:48.577296', 'station_id': 'Station_C', 'PM2.5': 175.3, 'CO2': 461.0, 'temperature': 16.2, 'humidity': 64.9, 'AQI': 234}
# Data stored for Station_C, Transaction Hash: 6b676b972aee8c2956f98ca14ac47617e568e9691384f8421fb2e04979bdfdea
# Sending row: {'timestamp': '2025-06-14 19:09:48.577332', 'station_id': 'Station_A', 'PM2.5': 84.2, 'CO2': 535.5, 'temperature': 17.6, 'humidity': 62.9, 'AQI': 251}
# Data stored for Station_A, Transaction Hash: 2713a8a87480d0be32f792dcee62bcb5b8a2171d24ef66a97930e8c348353b43
# Sending row: {'timestamp': '2025-06-15 10:25:48.577367', 'station_id': 'Station_B', 'PM2.5': 124.1, 'CO2': 322.5, 'temperature': 15.1, 'humidity': 60.4, 'AQI': 124}
# Data stored for Station_B, Transaction Hash: 8312b432fb492a1b7c8185daf04bf84eedd420837cfe4f13f7002229af5cee24
#
# Total IoT records stored: 100
# First stored record: [1749988033, 'Station_C', 146, 390, 25, 44, 105]
